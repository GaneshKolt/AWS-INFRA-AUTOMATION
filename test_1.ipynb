# %% [markdown]
# <a href="https://colab.research.google.com/github/GaneshKolt/AWS-INFRA-AUTOMATION/blob/master/test_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INSTALLING TENSORFLOW-**GPU**

# %%
# !pip install tensorflow-gpu

# %%
# !pip install pillow
# !pip install lxml
# !pip install jupyter
# !pip install matplotlib

# %%
# !git clone https://github.com/tensorflow/models.git

# %%
# %cd models/research/
# %set_env PYTHONPATH=/content/models/research:/content/models/research/slim

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !pwd
# Out:
# /content/models/research

# %%
# !python object_detection/builders/model_builder_test.py

# %%
# %cd /content/models/research

# %%
# !sudo python3 setup.py install

# %%
# !unzip /content/object-detection.zip
# Out:
# Archive:  /content/object-detection.zip
#    creating: object-detection/data/
#   inflating: object-detection/data/test_labels.csv
#   inflating: object-detection/data/train_labels.csv
#   inflating: object-detection/generate_tfrecord.py
#    creating: object-detection/images/
#    creating: object-detection/images/test/
#   inflating: object-detection/images/test/1.jpeg
#   inflating: object-detection/images/test/1.xml
#   inflating: object-detection/images/test/11.jpeg
#   inflating: object-detection/images/test/11.xml
#   inflating: object-detection/images/test/13.jpeg
#   inflating: object-detection/images/test/13.xml
#   inflating: object-detection/images/test/15.jpeg
#   inflating: object-detection/images/test/15.xml
#   inflating: object-detection/images/test/17.jpeg
#   inflating: object-detection/images/test/17.xml
#   inflating: object-detection/images/test/19.jpeg
#   inflating: object-detection/images/test/19.xml
#   inflating: object-detection/images/test/21.jpeg
# ...

# %%
# !pwd
# Out:
# /content/models/research

# %%
# !rm -rf /content/models/research/object-detection

# %%
# %cd ..
# Out:
# /content

# %%
# %cd object-detection/
# Out:
# /content/object-detection

# %%
# !python3 generate_tfrecord.py --csv_input=data/train_labels.csv --output_path=data/train.record --image_dir=images/train

# %%
# !python3 generate_tfrecord.py --csv_input=data/test_labels.csv --output_path=data/test.record --image_dir=images/test

# %%
# !wget http://download.tensorflow.org/models/object_detection/faster_rcnn_inception_v2_coco_2018_01_28.tar.gz

# %%
# !tar -xzvf faster_rcnn_inception_v2_coco_2018_01_28.tar.gz
# Out:
# faster_rcnn_inception_v2_coco_2018_01_28/
# faster_rcnn_inception_v2_coco_2018_01_28/model.ckpt.index
# faster_rcnn_inception_v2_coco_2018_01_28/checkpoint
# faster_rcnn_inception_v2_coco_2018_01_28/pipeline.config
# faster_rcnn_inception_v2_coco_2018_01_28/model.ckpt.data-00000-of-00001
# faster_rcnn_inception_v2_coco_2018_01_28/model.ckpt.meta
# faster_rcnn_inception_v2_coco_2018_01_28/saved_model/
# faster_rcnn_inception_v2_coco_2018_01_28/saved_model/saved_model.pb
# faster_rcnn_inception_v2_coco_2018_01_28/saved_model/variables/
# faster_rcnn_inception_v2_coco_2018_01_28/frozen_inference_graph.pb

# %%
# !pwd
# Out:
# /content/object-detection

# %%
cp -avr /content/object-detection/training /content/models/research/object_detection

# %%
# %cd ..
# Out:
# /content

# %%
# Out:
# /content/models/research/object_detection

# %%
# !python3 legacy/train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/faster_rcnn_inception_v2_coco.config
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0824 20:25:48.850332 140290787784576 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0824 20:25:49.063854 140290787784576 deprecation_wrapper.py:119] From /content/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0824 20:25:49.073289 140290787784576 deprecation_wrapper.py:119] From /content/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# ...

# %%
# !python3 export_inference_graph.py \
    --input_type image_tensor \
    --pipeline_config_path training/faster_rcnn_inception_v2_coco.config \
    --trained_checkpoint_prefix training/model.ckpt-324 \
    --output_directory ganesh_kolt_graph
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0824 20:44:02.908211 139803937400704 deprecation_wrapper.py:119] From /content/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0824 20:44:02.918254 139803937400704 deprecation_wrapper.py:119] From /content/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# W0824 20:44:02.929350 139803937400704 deprecation_wrapper.py:119] From export_inference_graph.py:162: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0824 20:44:02.929967 139803937400704 deprecation_wrapper.py:119] From export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...
